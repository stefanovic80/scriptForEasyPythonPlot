# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %matplotlib qt

# %%
wsx = input("Type an integer value for the x window size ")
wsy = input("Type an integer value for the y window size ")
xlim = input("Type a two values list for x limits ")
xlim = xlim.split()
xlim = list(map(float, xlim))
ylim = input("Type a two values list for y limits ")
ylim = ylim.split()
ylim = list(map(float, ylim))
xlabel = input("Type here the x label string ")
ylabel = input("Type here the y label string ")

if 'x1' not in globals():
  x1 = []

if 'y1' not in globals():
  y1 = []

if 'fig' not in globals():
    fig = plt.figure(figsize = (int(wsx), int(wsy) ) )
ax = fig.add_subplot(111)
ax.set_xlim(float(xlim[0]), float(xlim[1]) )
ax.set_ylim(float(ylim[0]), float(ylim[1]) )
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.grid()
line1, = ax.plot(x1, y1)#, label = '')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="900">
